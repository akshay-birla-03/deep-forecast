# %% [markdown]
# # Deep Forecast — one-click run
#
# This notebook clones the repository, installs it, and runs the demo end-to-end. **Runtime → Run all**.
#
# Runs fully on the free Colab CPU runtime — no API keys, no data downloads (all demo data is generated in code).

# %% [markdown]
# ### 1. Clone the repository

# %%
import os
if not os.path.isdir('/content/deep-forecast'):
    # !git clone -q https://github.com/akshay-birla-03/deep-forecast.git /content/deep-forecast
# %cd /content/deep-forecast

# %% [markdown]
# ### 2. Install

# %%
# Colab ships with a CPU/GPU build of PyTorch already, which satisfies the
# torch dependency. This just installs the package itself.
# !pip install -q -e .

# %% [markdown]
# ### 3. Run the demo

# %%
# !deepforecast --series 30 --length 240 --epochs 8
